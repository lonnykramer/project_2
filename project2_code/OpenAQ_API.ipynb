# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
# do pip install py-openaq in the pandas environment
import openaq
from pprint import pprint

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %%
engine = create_engine("sqlite:///output_data/airquality2.sqlite")

# %%
# api = openaq.OpenAQ()
# res = api.measurements(city='St. Louis', parameter='pm25', limit=10000, df=True)
# res = res.query("value >= 0.0")
# # g = sns.FacetGrid(data=res, col='location', col_wrap=4, size=3, sharex=True, sharey=False)
# # g.map(plt.hist, "value")
# # print(res)
# res.dtypes
# stl_df = pd.DataFrame(res)
# stl_df

api = openaq.OpenAQ()
res = api.measurements(country='US', parameter='pm25', limit=10000, df=True)

res = res.query("value >= 0.0")
# g = sns.FacetGrid(data=res, col='location', col_wrap=4, size=3, sharex=True, sharey=False)

# g.map(plt.hist, "value")
# print(res)
res.dtypes

us_df_pm25 = pd.DataFrame(res)
us_df_pm25.head()
# Out:
#                              location parameter  value  \
# date.local
# 2019-11-16 10:00:00   Blue Ridge I-70      pm25    7.4
# 2019-11-16 10:00:00       ARNOLD WEST      pm25   18.4
# 2019-11-16 10:00:00             Ladue      pm25   23.1
# 2019-11-16 10:00:00  BROADWAY (South)      pm25   17.1
# 2019-11-16 10:00:00     Branch Street      pm25   19.7
#
#                                        unit country              city  \
# date.local
# 2019-11-16 10:00:00  b'\xc2\xb5g/m\xc2\xb3'      US       Kansas City
# 2019-11-16 10:00:00  b'\xc2\xb5g/m\xc2\xb3'      US         St. Louis
# 2019-11-16 10:00:00  b'\xc2\xb5g/m\xc2\xb3'      US         St. Louis
# 2019-11-16 10:00:00  b'\xc2\xb5g/m\xc2\xb3'      US         St. Louis
# 2019-11-16 10:00:00  b'\xc2\xb5g/m\xc2\xb3'      US  ST. LOUIS (CITY)
#
#                                      date.utc  coordinates.latitude  \
# date.local
# 2019-11-16 10:00:00 2019-11-16 16:00:00+00:00             39.047911
# 2019-11-16 10:00:00 2019-11-16 16:00:00+00:00             38.448581
# 2019-11-16 10:00:00 2019-11-16 16:00:00+00:00             38.650259
# 2019-11-16 10:00:00 2019-11-16 16:00:00+00:00             38.542500
# 2019-11-16 10:00:00 2019-11-16 16:00:00+00:00             38.656430
#
#                      coordinates.longitude
# date.local
# 2019-11-16 10:00:00             -94.450513
# 2019-11-16 10:00:00             -90.398436
# 2019-11-16 10:00:00             -90.350463
# 2019-11-16 10:00:00             -90.263611
# 2019-11-16 10:00:00             -90.189770

# %%
pm25_groupby = us_df_pm25.groupby('location')
pm25_first = pm25_groupby.first()

pm25mean = us_df_pm25.groupby('location').mean()
pm25mean = pm25mean.rename(columns = {"value": "avgvalue", "coordinates.latitude": "lat", "coordinates.longitude": "lng"})

pm25 = pd.merge(pm25_first, pm25mean, on = 'location')
pm25 = pm25.drop(['value','lat','lng'], axis=1)
pm25 = pm25.rename(columns = {"coordinates.latitude": "coordinates_latitude", "coordinates.longitude": "coordinates_longitude"})

# create table schema ourselves
engine.execute("""CREATE TABLE pm25 (
        location TEXT,
        parameter TEXT,
        unit TEXT,
        country TEXT,
        city TEXT,
        "date.utc" TIMESTAMP,
        "coordinates_latitude" FLOAT,
        "coordinates_longitude" FLOAT,
        avgvalue FLOAT
, primary key("location"));""")

pm25.to_sql(name='pm25', con=engine, index=True, index_label='location',if_exists='append')

pm25.head()
# Out:
#              parameter                    unit country  \
# location
# 2912 Coffey       pm25  b'\xc2\xb5g/m\xc2\xb3'      US
# ADEQ-DSR          pm25  b'\xc2\xb5g/m\xc2\xb3'      US
# AIR LAB           pm25  b'\xc2\xb5g/m\xc2\xb3'      US
# ALLEN PARK        pm25  b'\xc2\xb5g/m\xc2\xb3'      US
# APOLLO BEACH      pm25  b'\xc2\xb5g/m\xc2\xb3'      US
#
#                                        city                  date.utc  \
# location
# 2912 Coffey            Omaha-Council Bluffs 2019-11-16 16:00:00+00:00
# ADEQ-DSR      Little Rock-North Little Rock 2019-11-16 10:00:00+00:00
# AIR LAB                           Knoxville 2019-11-16 16:00:00+00:00
# ALLEN PARK           Detroit-Warren-Livonia 2019-11-16 16:00:00+00:00
# APOLLO BEACH                   HILLSBOROUGH 2019-11-16 16:00:00+00:00
#
#               coordinates_latitude  coordinates_longitude   avgvalue
# location
# 2912 Coffey              41.133317             -95.956078   8.500000
# ADEQ-DSR                 34.681100             -92.328300  13.450000
# AIR LAB                  35.980300             -83.930600   8.178571
# ALLEN PARK               42.228300             -83.209200   5.178571
# APOLLO BEACH             27.779712             -82.419835   2.600000

# %%
api = openaq.OpenAQ()
res = api.measurements(country='US', parameter='bc', limit=9999, df=True)

res = res.query("value >= 0.0")
# g = sns.FacetGrid(data=res, col='location', col_wrap=4, size=3, sharex=True, sharey=False)

# g.map(plt.hist, "value")
# print(res)
res.dtypes

us_df_bc = pd.DataFrame(res)
us_df_bc.head()
# Out:
#                                  location parameter  value  \
# date.local
# 2019-11-16 08:00:00  Berkeley Aquatic Par        bc   0.51
# 2019-11-16 08:00:00  Arden Arcade - Del P        bc   0.00
# 2019-11-16 08:00:00    Portland Near Road        bc   1.80
# 2019-11-16 10:00:00            Gary-IITRI        bc   0.40
# 2019-11-16 11:00:00  Indpls-Washington Pa        bc   1.33
#
#                                        unit country  \
# date.local
# 2019-11-16 08:00:00  b'\xc2\xb5g/m\xc2\xb3'      US
# 2019-11-16 08:00:00  b'\xc2\xb5g/m\xc2\xb3'      US
# 2019-11-16 08:00:00  b'\xc2\xb5g/m\xc2\xb3'      US
# 2019-11-16 10:00:00  b'\xc2\xb5g/m\xc2\xb3'      US
# 2019-11-16 11:00:00  b'\xc2\xb5g/m\xc2\xb3'      US
#
#                                                     city  \
# date.local
# 2019-11-16 08:00:00                              ALAMEDA
# 2019-11-16 08:00:00  Sacramento--Arden-Arcade--Roseville
# 2019-11-16 08:00:00         Portland-Vancouver-Beaverton
# 2019-11-16 10:00:00            Chicago-Naperville-Joliet
# 2019-11-16 11:00:00                         Indianapolis
#
#                                      date.utc  coordinates.latitude  \
# date.local
# 2019-11-16 08:00:00 2019-11-16 16:00:00+00:00             37.864767
# 2019-11-16 08:00:00 2019-11-16 16:00:00+00:00             38.613804
# 2019-11-16 08:00:00 2019-11-16 16:00:00+00:00             45.399160
# 2019-11-16 10:00:00 2019-11-16 16:00:00+00:00             41.606700
# 2019-11-16 11:00:00 2019-11-16 16:00:00+00:00             39.810800
#
#                      coordinates.longitude
# date.local
# 2019-11-16 08:00:00            -122.302741
# 2019-11-16 08:00:00            -121.368007
# 2019-11-16 08:00:00            -122.745500
# 2019-11-16 10:00:00             -87.304700
# 2019-11-16 11:00:00             -86.114700

# %%
bc_groupby = us_df_bc.groupby('location')
bc_first = bc_groupby.first()

bcmean = us_df_bc.groupby('location').mean()
bcmean = bcmean.rename(columns = {"value": "avgvalue", "coordinates.latitude": "lat", "coordinates.longitude": "lng"})

bc = pd.merge(bc_first, bcmean, on = 'location')
bc = bc.drop(['value','lat','lng'], axis=1)
bc = bc.rename(columns = {"coordinates.latitude": "coordinates_latitude", "coordinates.longitude": "coordinates_longitude"})

engine.execute("""CREATE TABLE bc (
        location TEXT,
        parameter TEXT,
        unit TEXT,
        country TEXT,
        city TEXT,
        "date.utc" TIMESTAMP,
        "coordinates_latitude" FLOAT,
        "coordinates_longitude" FLOAT,
        avgvalue FLOAT
, primary key("location"));""")

bc.to_sql(name='bc', con=engine, index=True, index_label='location', if_exists='append')

bc.head()
# Out:
#                      parameter                    unit country  \
# location
# Arden Arcade - Del P        bc  b'\xc2\xb5g/m\xc2\xb3'      US
# Berkeley Aquatic Par        bc  b'\xc2\xb5g/m\xc2\xb3'      US
# E Providence                bc  b'\xc2\xb5g/m\xc2\xb3'      US
# Elkhart-Prairie St.         bc  b'\xc2\xb5g/m\xc2\xb3'      US
# Evansville-Buena Vis        bc  b'\xc2\xb5g/m\xc2\xb3'      US
#
#                                                      city  \
# location
# Arden Arcade - Del P  Sacramento--Arden-Arcade--Roseville
# Berkeley Aquatic Par                              ALAMEDA
# E Providence            Providence-New Bedford-Fall River
# Elkhart-Prairie St.                        Elkhart-Goshen
# Evansville-Buena Vis                           Evansville
#
#                                       date.utc  coordinates_latitude  \
# location
# Arden Arcade - Del P 2019-11-16 16:00:00+00:00             38.613804
# Berkeley Aquatic Par 2019-11-16 16:00:00+00:00             37.864767
# E Providence         2019-11-16 13:00:00+00:00             41.840302
# Elkhart-Prairie St.  2019-11-16 16:00:00+00:00             41.656944
# Evansville-Buena Vis 2019-11-16 16:00:00+00:00             38.013300
#
#                       coordinates_longitude  avgvalue
# location
# Arden Arcade - Del P            -121.368007  0.827586
# Berkeley Aquatic Par            -122.302741  1.256881
# E Providence                     -71.361702  0.397548
# Elkhart-Prairie St.              -85.968330  4.012271
# Evansville-Buena Vis             -87.577200  0.589354

# %%
api = openaq.OpenAQ()
res = api.measurements(country='US', parameter='pm10', limit=10000, df=True)

res = res.query("value >= 0.0")
# g = sns.FacetGrid(data=res, col='location', col_wrap=4, size=3, sharex=True, sharey=False)

# g.map(plt.hist, "value")
# print(res)
res.dtypes

us_df_pm10 = pd.DataFrame(res)
us_df_pm10.head()
# Out:
#                            location parameter  value                    unit  \
# date.local
# 2019-11-16 11:00:00        CARTHAGE      pm10      8  b'\xc2\xb5g/m\xc2\xb3'
# 2019-11-16 11:00:00     ARNOLD WEST      pm10     12  b'\xc2\xb5g/m\xc2\xb3'
# 2019-11-16 11:00:00            MTSP      pm10     14  b'\xc2\xb5g/m\xc2\xb3'
# 2019-11-16 11:00:00   Branch Street      pm10     20  b'\xc2\xb5g/m\xc2\xb3'
# 2019-11-16 09:00:00  Mesa 2 /Nipomo      pm10     43  b'\xc2\xb5g/m\xc2\xb3'
#
#                     country                         city  \
# date.local
# 2019-11-16 11:00:00      US                       Joplin
# 2019-11-16 11:00:00      US                    St. Louis
# 2019-11-16 11:00:00      US                       MONROE
# 2019-11-16 11:00:00      US             ST. LOUIS (CITY)
# 2019-11-16 09:00:00      US  San Luis Obispo-Paso Robles
#
#                                      date.utc  coordinates.latitude  \
# date.local
# 2019-11-16 11:00:00 2019-11-16 17:00:00+00:00             37.198220
# 2019-11-16 11:00:00 2019-11-16 17:00:00+00:00             38.448581
# 2019-11-16 11:00:00 2019-11-16 17:00:00+00:00             39.475100
# 2019-11-16 11:00:00 2019-11-16 17:00:00+00:00             38.656430
# 2019-11-16 09:00:00 2019-11-16 17:00:00+00:00             35.020790
#
#                      coordinates.longitude
# date.local
# 2019-11-16 11:00:00             -94.317020
# 2019-11-16 11:00:00             -90.398436
# 2019-11-16 11:00:00             -91.788990
# 2019-11-16 11:00:00             -90.189770
# 2019-11-16 09:00:00            -120.563890

# %%
pm10_groupby = us_df_pm10.groupby('location')
pm10_first = pm10_groupby.first()

pm10mean = us_df_pm10.groupby('location').mean()
pm10mean = pm10mean.rename(columns = {"value": "avgvalue", "coordinates.latitude": "lat", "coordinates.longitude": "lng"})

pm10 = pd.merge(pm10_first, pm10mean, on = 'location')
pm10 = pm10.drop(['value','lat','lng'], axis=1)
pm10 = pm10.rename(columns = {"coordinates.latitude": "coordinates_latitude", "coordinates.longitude": "coordinates_longitude"})

engine.execute("""CREATE TABLE pm10 (
        location TEXT,
        parameter TEXT,
        unit TEXT,
        country TEXT,
        city TEXT,
        "date.utc" TIMESTAMP,
        "coordinates_latitude" FLOAT,
        "coordinates_longitude" FLOAT,
        avgvalue FLOAT
, primary key("location"));""")

pm10.to_sql(name='pm10', con=engine, index=True, index_label='location',if_exists='append')

pm10.head()
# Out:
#                   parameter                    unit country       city  \
# location
# 7E Deming Airport      pm10  b'\xc2\xb5g/m\xc2\xb3'      US     Deming
# ARNOLD                 pm10  b'\xc2\xb5g/m\xc2\xb3'      US  St. Louis
# ARNOLD WEST            pm10  b'\xc2\xb5g/m\xc2\xb3'      US  St. Louis
# Ajo                    pm10  b'\xc2\xb5g/m\xc2\xb3'      US       PIMA
# Alamo Lake             pm10  b'\xc2\xb5g/m\xc2\xb3'      US     LA PAZ
#
#                                    date.utc  coordinates_latitude  \
# location
# 7E Deming Airport 2019-11-16 13:00:00+00:00             32.255800
# ARNOLD            2019-11-15 13:00:00+00:00             38.448581
# ARNOLD WEST       2019-11-16 17:00:00+00:00             38.448581
# Ajo               2019-11-16 16:00:00+00:00             32.382034
# Alamo Lake        2019-11-16 16:00:00+00:00             34.243889
#
#                    coordinates_longitude   avgvalue
# location
# 7E Deming Airport            -107.722800  21.457143
# ARNOLD                        -90.398436  14.222222
# ARNOLD WEST                   -90.398436  19.296296
# Ajo                          -112.857452  32.571429
# Alamo Lake                   -113.558611  15.763158

# %%
api = openaq.OpenAQ()
res = api.measurements(country='US', parameter='so2', limit=10000, df=True)

res = res.query("value >= 0.0")
# g = sns.FacetGrid(data=res, col='location', col_wrap=4, size=3, sharex=True, sharey=False)

# g.map(plt.hist, "value")
# print(res)
res.dtypes

us_df_so2 = pd.DataFrame(res)
us_df_so2.head()
# Out:
#                                  location parameter  value unit country  \
# date.local
# 2019-11-16 11:00:00  Herculaneum, Mott St       so2  0.001  ppm      US
# 2019-11-16 11:00:00      Rider Trail I-70       so2  0.002  ppm      US
# 2019-11-16 11:00:00          BLAIR STREET       so2  0.001  ppm      US
# 2019-11-16 11:00:00       Sheldon Station       so2  0.000  ppm      US
# 2019-11-16 09:00:00        Mesa 2 /Nipomo       so2  0.000  ppm      US
#
#                                             city                  date.utc  \
# date.local
# 2019-11-16 11:00:00                    St. Louis 2019-11-16 17:00:00+00:00
# 2019-11-16 11:00:00                    ST. LOUIS 2019-11-16 17:00:00+00:00
# 2019-11-16 11:00:00                    St. Louis 2019-11-16 17:00:00+00:00
# 2019-11-16 11:00:00                    LANCASTER 2019-11-16 17:00:00+00:00
# 2019-11-16 09:00:00  San Luis Obispo-Paso Robles 2019-11-16 17:00:00+00:00
#
#                      coordinates.latitude  coordinates.longitude
# date.local
# 2019-11-16 11:00:00             38.263394             -90.379667
# 2019-11-16 11:00:00             38.752640             -90.448840
# 2019-11-16 11:00:00             38.656449             -90.198548
# 2019-11-16 11:00:00             40.554760             -96.780350
# 2019-11-16 09:00:00             35.020790            -120.563890

# %%
so2_groupby = us_df_so2.groupby('location')
so2_first = so2_groupby.first()

so2mean = us_df_so2.groupby('location').mean()
so2mean = so2mean.rename(columns = {"value": "avgvalue", "coordinates.latitude": "lat", "coordinates.longitude": "lng"})

so2 = pd.merge(so2_first, so2mean, on = 'location')
so2 = so2.drop(['value','lat','lng'], axis=1)
so2 = so2.rename(columns = {"coordinates.latitude": "coordinates_latitude", "coordinates.longitude": "coordinates_longitude"})

engine.execute("""CREATE TABLE so2 (
        location TEXT,
        parameter TEXT,
        unit TEXT,
        country TEXT,
        city TEXT,
        "date.utc" TIMESTAMP,
        "coordinates_latitude" FLOAT,
        "coordinates_longitude" FLOAT,
        avgvalue FLOAT
, primary key("location"));""")

so2.to_sql(name='so2', con=engine, index=True, index_label='location',if_exists='append')

so2.head()
# Out:
#                      parameter unit country                    city  \
# location
# 16th and Whitmore          so2  ppm      US    Omaha-Council Bluffs
# ALLEN PARK                 so2  ppm      US  Detroit-Warren-Livonia
# APOLLO BEACH               so2  ppm      US            HILLSBOROUGH
# Acadia NP - McFarlan       so2  ppm      US                 HANCOCK
# Akron NIFH/STEM            so2  ppm      US                   Akron
#
#                                       date.utc  coordinates_latitude  \
# location
# 16th and Whitmore    2019-11-16 16:00:00+00:00             41.322472
# ALLEN PARK           2019-11-16 16:00:00+00:00             42.228300
# APOLLO BEACH         2019-11-16 16:00:00+00:00             27.779712
# Acadia NP - McFarlan 2019-11-16 16:00:00+00:00             44.377048
# Akron NIFH/STEM      2019-11-16 16:00:00+00:00             41.079140
#
#                       coordinates_longitude  avgvalue
# location
# 16th and Whitmore                -95.937992  0.000211
# ALLEN PARK                       -83.209200  0.001196
# APOLLO BEACH                     -82.419835  0.000326
# Acadia NP - McFarlan             -68.260902  0.000000
# Akron NIFH/STEM                  -81.516270  0.000000

# %%
api = openaq.OpenAQ()
res = api.measurements(country='US', parameter='no2', limit=10000, df=True)

res = res.query("value >= 0.0")
# g = sns.FacetGrid(data=res, col='location', col_wrap=4, size=3, sharex=True, sharey=False)

# g.map(plt.hist, "value")
# print(res)
res.dtypes

us_df_no2 = pd.DataFrame(res)
us_df_no2.head()
# Out:
#                              location parameter  value unit country  \
# date.local
# 2019-11-16 11:00:00              MTSP       no2  0.005  ppm      US
# 2019-11-16 11:00:00  Rider Trail I-70       no2  0.008  ppm      US
# 2019-11-16 11:00:00      BLAIR STREET       no2  0.008  ppm      US
# 2019-11-16 11:00:00       Forest Park       no2  0.016  ppm      US
# 2019-11-16 09:00:00         Nipomo RP       no2  0.002  ppm      US
#
#                                             city                  date.utc  \
# date.local
# 2019-11-16 11:00:00                       MONROE 2019-11-16 17:00:00+00:00
# 2019-11-16 11:00:00                    ST. LOUIS 2019-11-16 17:00:00+00:00
# 2019-11-16 11:00:00                    St. Louis 2019-11-16 17:00:00+00:00
# 2019-11-16 11:00:00                    St. Louis 2019-11-16 17:00:00+00:00
# 2019-11-16 09:00:00  San Luis Obispo-Paso Robles 2019-11-16 17:00:00+00:00
#
#                      coordinates.latitude  coordinates.longitude
# date.local
# 2019-11-16 11:00:00             39.475100             -91.788990
# 2019-11-16 11:00:00             38.752640             -90.448840
# 2019-11-16 11:00:00             38.656449             -90.198548
# 2019-11-16 11:00:00             38.631057             -90.281144
# 2019-11-16 09:00:00             35.031500            -120.501010

# %%
no2_groupby = us_df_no2.groupby('location')
no2_first = no2_groupby.first()

no2mean = us_df_no2.groupby('location').mean()
no2mean = no2mean.rename(columns = {"value": "avgvalue", "coordinates.latitude": "lat", "coordinates.longitude": "lng"})

no2 = pd.merge(no2_first, no2mean, on = 'location')
no2 = no2.drop(['value','lat','lng'], axis=1)
no2 = no2.rename(columns = {"coordinates.latitude": "coordinates_latitude", "coordinates.longitude": "coordinates_longitude"})

engine.execute("""CREATE TABLE no2 (
        location TEXT,
        parameter TEXT,
        unit TEXT,
        country TEXT,
        city TEXT,
        "date.utc" TIMESTAMP,
        "coordinates_latitude" FLOAT,
        "coordinates_longitude" FLOAT,
        avgvalue FLOAT
, primary key("location"));""")

no2.to_sql(name='no2', con=engine, index=True, index_label='location',if_exists='append')

no2.head()
# Out:
#                   parameter unit country                              city  \
# location
# 60 Near Road            no2  ppm      US                    SAN BERNARDINO
# 710 Near Road           no2  ppm      US                       LOS ANGELES
# AURORA HILLS            no2  ppm      US   Washington-Arlington-Alexandria
# Anaheim                 no2  ppm      US  Los Angeles-Long Beach-Santa Ana
# Anaheim Near Road       no2  ppm      US                            ORANGE
#
#                                    date.utc  coordinates_latitude  \
# location
# 60 Near Road      2019-11-16 16:00:00+00:00             34.030900
# 710 Near Road     2019-11-16 16:00:00+00:00             33.859662
# AURORA HILLS      2019-11-16 16:00:00+00:00             38.859402
# Anaheim           2019-11-16 16:00:00+00:00             33.830586
# Anaheim Near Road 2019-11-16 16:00:00+00:00             33.819305
#
#                    coordinates_longitude  avgvalue
# location
# 60 Near Road                 -117.617403  0.035690
# 710 Near Road                -118.200707  0.033214
# AURORA HILLS                  -77.058899  0.023024
# Anaheim                      -117.938509  0.020738
# Anaheim Near Road            -117.918759  0.022756

# %%
api = openaq.OpenAQ()
res = api.measurements(country='US', parameter='o3', limit=10000, df=True)

res = res.query("value >= 0.0")
# g = sns.FacetGrid(data=res, col='location', col_wrap=4, size=3, sharex=True, sharey=False)

# g.map(plt.hist, "value")
# print(res)
res.dtypes

us_df_o3 = pd.DataFrame(res)
us_df_o3.head()
# Out:
#                               location parameter  value unit country  \
# date.local
# 2019-11-16 11:00:00               MTSP        o3  0.029  ppm      US
# 2019-11-16 11:00:00       BLAIR STREET        o3  0.021  ppm      US
# 2019-11-16 12:00:00         Kittanning        o3  0.038  ppm      US
# 2019-11-16 12:00:00          Hookstown        o3  0.035  ppm      US
# 2019-11-16 12:00:00  Brighton Township        o3  0.038  ppm      US
#
#                            city                  date.utc  \
# date.local
# 2019-11-16 11:00:00      MONROE 2019-11-16 17:00:00+00:00
# 2019-11-16 11:00:00   St. Louis 2019-11-16 17:00:00+00:00
# 2019-11-16 12:00:00  Pittsburgh 2019-11-16 17:00:00+00:00
# 2019-11-16 12:00:00  Pittsburgh 2019-11-16 17:00:00+00:00
# 2019-11-16 12:00:00  Pittsburgh 2019-11-16 17:00:00+00:00
#
#                      coordinates.latitude  coordinates.longitude
# date.local
# 2019-11-16 11:00:00             39.475100             -91.788990
# 2019-11-16 11:00:00             38.656449             -90.198548
# 2019-11-16 12:00:00             40.814200             -79.565000
# 2019-11-16 12:00:00             40.562500             -80.504200
# 2019-11-16 12:00:00             40.684700             -80.359700

# %%
o3_groupby = us_df_o3.groupby('location')
o3_first = o3_groupby.first()

o3mean = us_df_o3.groupby('location').mean()
o3mean = o3mean.rename(columns = {"value": "avgvalue", "coordinates.latitude": "lat", "coordinates.longitude": "lng"})

o3 = pd.merge(o3_first, o3mean, on = 'location')
o3 = o3.drop(['value','lat','lng'], axis=1)
o3 = o3.rename(columns = {"coordinates.latitude": "coordinates_latitude", "coordinates.longitude": "coordinates_longitude"})

# create table schema ourselves
engine.execute("""CREATE TABLE o3 (
        location TEXT,
        parameter TEXT,
        unit TEXT,
        country TEXT,
        city TEXT,
        "date.utc" TIMESTAMP,
        "coordinates_latitude" FLOAT,
        "coordinates_longitude" FLOAT,
        avgvalue FLOAT
, primary key("location"));""")

o3.to_sql(name='o3', con=engine, index=True, index_label="location",if_exists='append')

o3.head()
# Out:
#                      parameter unit country                       city  \
# location
# 22nd Street & Craycr        o3  ppm      US                     Tucson
# 2LL Los Lunas               o3  ppm      US                Albuquerque
# AJ Maintenance Yard         o3  ppm      US    Phoenix-Mesa-Scottsdale
# ALLEN PARK                  o3  ppm      US     Detroit-Warren-Livonia
# ALSIP                       o3  ppm      US  Chicago-Naperville-Joliet
#
#                                       date.utc  coordinates_latitude  \
# location
# 22nd Street & Craycr 2019-11-16 16:00:00+00:00             32.205000
# 2LL Los Lunas        2019-11-16 13:00:00+00:00             34.814700
# AJ Maintenance Yard  2019-11-16 16:00:00+00:00             33.420601
# ALLEN PARK           2019-11-16 16:00:00+00:00             42.228300
# ALSIP                2019-11-16 16:00:00+00:00             41.670800
#
#                       coordinates_longitude  avgvalue
# location
# 22nd Street & Craycr            -110.877200  0.027467
# 2LL Los Lunas                   -106.739700  0.009455
# AJ Maintenance Yard             -111.503304  0.043786
# ALLEN PARK                       -83.209200  0.014600
# ALSIP                            -87.732500  0.003000

# %%
api = openaq.OpenAQ()
res = api.measurements(country='US', parameter='co', limit=10000, df=True)

res = res.query("value >= 0.0")
# g = sns.FacetGrid(data=res, col='location', col_wrap=4, size=3, sharex=True, sharey=False)

# g.map(plt.hist, "value")
# print(res)
res.dtypes

us_df_co = pd.DataFrame(res)
us_df_co.head()
# Out:
#                          location parameter  value unit country       city  \
# date.local
# 2019-11-16 11:00:00  BLAIR STREET        co   0.08  ppm      US  St. Louis
# 2019-11-16 11:00:00   Forest Park        co   0.32  ppm      US  St. Louis
# 2019-11-16 10:00:00         Ute 1        co   0.20  ppm      US    Durango
# 2019-11-16 12:00:00         NCORE        co   0.13  ppm      US    BROWARD
# 2019-11-16 12:00:00     Near Road        co   0.15  ppm      US    BROWARD
#
#                                      date.utc  coordinates.latitude  \
# date.local
# 2019-11-16 11:00:00 2019-11-16 17:00:00+00:00             38.656449
# 2019-11-16 11:00:00 2019-11-16 17:00:00+00:00             38.631057
# 2019-11-16 10:00:00 2019-11-16 17:00:00+00:00             37.136780
# 2019-11-16 12:00:00 2019-11-16 17:00:00+00:00             26.054047
# 2019-11-16 12:00:00 2019-11-16 17:00:00+00:00             26.131256
#
#                      coordinates.longitude
# date.local
# 2019-11-16 11:00:00             -90.198548
# 2019-11-16 11:00:00             -90.281144
# 2019-11-16 10:00:00            -107.628630
# 2019-11-16 12:00:00             -80.257608
# 2019-11-16 12:00:00             -80.167847

# %%
co_groupby = us_df_co.groupby('location')
co_first = co_groupby.first()

comean = us_df_co.groupby('location').mean()
comean = comean.rename(columns = {"value": "avgvalue", "coordinates.latitude": "lat", "coordinates.longitude": "lng"})

co = pd.merge(co_first, comean, on = 'location')
co = co.drop(['value','lat','lng'], axis=1)
co = co.rename(columns = {"coordinates.latitude": "coordinates_latitude", "coordinates.longitude": "coordinates_longitude"})

engine.execute("""CREATE TABLE co (
        location TEXT,
        parameter TEXT,
        unit TEXT,
        country TEXT,
        city TEXT,
        "date.utc" TIMESTAMP,
        "coordinates_latitude" FLOAT,
        "coordinates_longitude" FLOAT,
        avgvalue FLOAT
, primary key("location"));""")
co.to_sql(name='co', con=engine, index=True, index_label='location',if_exists='append')

co.head()
# Out:
#                   parameter unit country                              city  \
# location
# 77th and Dodge           co  ppm      US              Omaha-Council Bluffs
# ALLEN PARK               co  ppm      US            Detroit-Warren-Livonia
# AURORA HILLS             co  ppm      US   Washington-Arlington-Alexandria
# Anaheim                  co  ppm      US  Los Angeles-Long Beach-Santa Ana
# Anaheim Near Road        co  ppm      US                            ORANGE
#
#                                    date.utc  coordinates_latitude  \
# location
# 77th and Dodge    2019-11-16 16:00:00+00:00             41.259478
# ALLEN PARK        2019-11-16 16:00:00+00:00             42.228300
# AURORA HILLS      2019-11-16 16:00:00+00:00             38.859402
# Anaheim           2019-11-16 16:00:00+00:00             33.830586
# Anaheim Near Road 2019-11-16 16:00:00+00:00             33.819305
#
#                    coordinates_longitude  avgvalue
# location
# 77th and Dodge                -96.034714  0.356066
# ALLEN PARK                    -83.209200  0.000159
# AURORA HILLS                  -77.058899  0.490164
# Anaheim                      -117.938509  0.456393
# Anaheim Near Road            -117.918759  0.725806

# %%
# api = openaq.OpenAQ()
# res2 = api.locations(coordinates='38.63, -90.20', radius='50000', limit=10000, df=True)

# # res2 = res2.query("value >= 0.0")
# # g = sns.FacetGrid(data=res, col='location', col_wrap=4, size=3, sharex=True, sharey=False)

# # g.map(plt.hist, "value")
# # print(res)
# res.dtypes

# stl_df2 = pd.DataFrame(res2)
# stl_df2

# %%
combinedaq = pd.concat([pm25, bc, pm10, so2, no2, o3, co], sort =False)
combinedaq
# Out:
#                      parameter                    unit country  \
# location
# 2912 Coffey               pm25  b'\xc2\xb5g/m\xc2\xb3'      US
# ADEQ-DSR                  pm25  b'\xc2\xb5g/m\xc2\xb3'      US
# AIR LAB                   pm25  b'\xc2\xb5g/m\xc2\xb3'      US
# ALLEN PARK                pm25  b'\xc2\xb5g/m\xc2\xb3'      US
# APOLLO BEACH              pm25  b'\xc2\xb5g/m\xc2\xb3'      US
# ...                        ...                     ...     ...
# West Los Angeles - V        co                     ppm      US
# West Phoenix                co                     ppm      US
# West Yellowstone Par        co                     ppm      US
# Winter Park                 co                     ppm      US
# Worcester                   co                     ppm      US
#
#                                                   city  \
# location
# 2912 Coffey                       Omaha-Council Bluffs
# ADEQ-DSR                 Little Rock-North Little Rock
# AIR LAB                                      Knoxville
# ALLEN PARK                      Detroit-Warren-Livonia
# APOLLO BEACH                              HILLSBOROUGH
# ...                                                ...
# West Los Angeles - V  Los Angeles-Long Beach-Santa Ana
# West Phoenix                   Phoenix-Mesa-Scottsdale
# West Yellowstone Par                          GALLATIN
# Winter Park                          Orlando-Kissimmee
# Worcester                                    Worcester
#
#                                       date.utc  coordinates_latitude  \
# location
# 2912 Coffey          2019-11-16 16:00:00+00:00             41.133317
# ADEQ-DSR             2019-11-16 10:00:00+00:00             34.681100
# AIR LAB              2019-11-16 16:00:00+00:00             35.980300
# ALLEN PARK           2019-11-16 16:00:00+00:00             42.228300
# APOLLO BEACH         2019-11-16 16:00:00+00:00             27.779712
# ...                                        ...                   ...
# West Los Angeles - V 2019-11-16 16:00:00+00:00             34.051097
# West Phoenix         2019-11-16 16:00:00+00:00             33.483799
# West Yellowstone Par 2019-11-16 16:00:00+00:00             44.657014
# Winter Park          2019-11-16 16:00:00+00:00             28.599700
# Worcester            2019-11-16 16:00:00+00:00             42.263901
#
#                       coordinates_longitude   avgvalue
# location
# 2912 Coffey                      -95.956078   8.500000
# ADEQ-DSR                         -92.328300  13.450000
# AIR LAB                          -83.930600   8.178571
# ALLEN PARK                       -83.209200   5.178571
# APOLLO BEACH                     -82.419835   2.600000
# ...                                     ...        ...
# West Los Angeles - V            -118.456386   0.435738
# West Phoenix                    -112.142601   1.283333
# West Yellowstone Par            -111.089618   0.153636
# Winter Park                      -81.362800   0.374468
# Worcester                        -71.794701   0.430000
#
# [2507 rows x 8 columns]

# %%
engine.execute("""CREATE TABLE combinedaq (
        location TEXT,
        parameter TEXT,
        unit TEXT,
        country TEXT,
        city TEXT,
        "date.utc" TIMESTAMP,
        "coordinates_latitude" FLOAT,
        "coordinates_longitude" FLOAT,
        avgvalue FLOAT
, primary key("location", "parameter"));""")
combinedaq.to_sql(name='combinedaq', con=engine, index=True, index_label='location',if_exists='append')

combinedaq.head()
# Out:
#              parameter                    unit country  \
# location
# 2912 Coffey       pm25  b'\xc2\xb5g/m\xc2\xb3'      US
# ADEQ-DSR          pm25  b'\xc2\xb5g/m\xc2\xb3'      US
# AIR LAB           pm25  b'\xc2\xb5g/m\xc2\xb3'      US
# ALLEN PARK        pm25  b'\xc2\xb5g/m\xc2\xb3'      US
# APOLLO BEACH      pm25  b'\xc2\xb5g/m\xc2\xb3'      US
#
#                                        city                  date.utc  \
# location
# 2912 Coffey            Omaha-Council Bluffs 2019-11-16 16:00:00+00:00
# ADEQ-DSR      Little Rock-North Little Rock 2019-11-16 10:00:00+00:00
# AIR LAB                           Knoxville 2019-11-16 16:00:00+00:00
# ALLEN PARK           Detroit-Warren-Livonia 2019-11-16 16:00:00+00:00
# APOLLO BEACH                   HILLSBOROUGH 2019-11-16 16:00:00+00:00
#
#               coordinates_latitude  coordinates_longitude   avgvalue
# location
# 2912 Coffey              41.133317             -95.956078   8.500000
# ADEQ-DSR                 34.681100             -92.328300  13.450000
# AIR LAB                  35.980300             -83.930600   8.178571
# ALLEN PARK               42.228300             -83.209200   5.178571
# APOLLO BEACH             27.779712             -82.419835   2.600000
